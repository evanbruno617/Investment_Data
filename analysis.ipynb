# %%
import pandas as pd

# %%
data = pd.read_csv('TD_Financials/Basic Materials Sector.csv')
data.head()
# Out:
#    Unnamed: 0.1 Unnamed: 0   peRatio  pegRatio  pbRatio  prRatio  pcfRatio  \
# 0             0       ASIX   6.71545  0.000000  1.21870  0.49294   4.29537
# 1             1        AEM  10.97336  0.070150  1.39363  4.64530   7.82980
# 2             2        APD  28.33656  0.000000  4.35435  4.66075  17.33001
# 3             3        AGI  59.00000  0.000000  0.00000  0.00000   0.00000
# 4             4        ALB   6.59601  0.005447  2.61865  2.75090   7.97561
#
#    grossMarginTTM  grossMarginMRQ  netProfitMarginTTM  ...  currentRatio  \
# 0        15.07971        17.60156             7.69997  ...       1.25466
# 1        56.15239        56.73572            40.12378  ...       2.31607
# 2        27.52910        28.66473            16.75943  ...       2.04496
# 3         0.00000         0.00000             0.00000  ...       0.00000
# 4        44.51684        49.47346            30.82611  ...       1.89925
#
#    totalDebtToCapital  ltDebtToEquity  totalDebtToEquity  revChangeTTM  \
# ...
